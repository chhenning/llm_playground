# %% [markdown]
# # Simple Test

# %%
import json

import requests

try:
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Name all countries in North America.",
        },
    ]

    data = {"messages": messages, "temperature": 0.7}
    response = requests.post(
        url="http://localhost:36912/v1/chat/completions",
        headers={
            "Content-Type": "application/json",
        },
        data=json.dumps(data),
    )
    response.raise_for_status()

    response_json = response.json()
    assistant_message = response_json["choices"][0]["message"]["content"]
    print(assistant_message.strip())

except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# North America consists of the following countries:
#
# 1. **Antigua and Barbuda**
# 2. **Bahamas**
# 3. **Barbados**
# 4. **Belize**
# 5. **Canada**
# 6. **Costa Rica**
# 7. **Cuba**
# 8. **Dominica**
# 9. **Dominican Republic**
# 10. **El Salvador**
# 11. **Grenada**
# 12. **Guatemala**
# 13. **Haiti**
# 14. **Honduras**
# 15. **Jamaica**
# 16. **Mexico**
# 17. **Nicaragua**
# 18. **Panama**
# 19. **Saint Kitts and Nevis**
# 20. **Saint Lucia**
# 21. **Saint Vincent and the Grenadines**
# 22. **Trinidad and Tobago**
# 23. **United States of America**
#
# These 23 countries are generally recognized as part of North America, including the Caribbean nations that are geographically and politically associated with the continent.
